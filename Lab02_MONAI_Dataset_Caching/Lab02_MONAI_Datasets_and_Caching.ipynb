# %% [markdown]
# # Lab 02: MONAI_Datasets_and_Caching
#
# <p align="center">
#   <img src="MONAI_LISA_5.png" width="400">
# </p>
#
#
#
# **MONAI_LISA** is a personal medical AI sandbox designed for exploring and experimenting with 3D medical image computing. Built on top of the [MONAI](https://monai.io/) framework. This Lab02 notebook is based on the **"2. MONAI Datasets and Caching"** tutorial from the **MONAI Bootcamp 2021**.
#
# ### 🔗 Useful Resources
# *   **GitHub Repository:** [MONAI Bootcamp 2021 - Day 1](https://github.com/Project-MONAI/MONAIBootcamp2021/tree/main/day1)
# *   **Video Tutorial:** [MONAI Bootcamp 2021 Playlist](https://www.youtube.com/watch?v=Da5sscGnnTE&list=PLtoSVSQ2XzyCobzE6NvwjNpITsQyPUtfs&index=3)
#
# ---
# **Adapted by:** Yun-An Huang
# **Date:** June 1st, 2026

# %%
## Initialization: Install MONAI and test the environment

from google.colab import drive
import os

# Install
# !pip install --index-url https://download.pytorch.org/whl/cu124 torch==2.6.0 torchvision==0.21.0 torchaudio==2.6.0
# !pip install "monai[all]" nibabel pydicom ipywidgets==8.1.2

# Clone
if not os.path.exists("tutorials"):
    # !git clone https://github.com/Project-MONAI/tutorials.git
    # !git clone https://github.com/Project-MONAI/MONAIBootcamp2021.git

# Test environment
import torch

print("GPU Avalable:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU type:", torch.cuda.get_device_name(0))
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu124
# Collecting torch==2.6.0
#   Downloading https://download-r2.pytorch.org/whl/cu124/torch-2.6.0%2Bcu124-cp312-cp312-linux_x86_64.whl.metadata (28 kB)
# Collecting torchvision==0.21.0
#   Downloading https://download-r2.pytorch.org/whl/cu124/torchvision-0.21.0%2Bcu124-cp312-cp312-linux_x86_64.whl.metadata (6.1 kB)
# Collecting torchaudio==2.6.0
#   Downloading https://download-r2.pytorch.org/whl/cu124/torchaudio-2.6.0%2Bcu124-cp312-cp312-linux_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0) (4.15.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch==2.6.0)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 82.5 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch==2.6.0)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 58.5 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch==2.6.0)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 107.8 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch==2.6.0)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 875.2 kB/s eta 0:00:0000:0100:01
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch==2.6.0)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch==2.6.0)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch==2.6.0)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.7 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch==2.6.0)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch==2.6.0)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.5 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cusparselt-cu12==0.6.2 (from torch==2.6.0)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch==2.6.0)
#   Downloading https://download.pytorch.org/whl/nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 5.9 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch==2.6.0)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 10.9 MB/s eta 0:00:00
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch==2.6.0)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 86.2 MB/s eta 0:00:0000:0100:01
# Collecting triton==3.2.0 (from torch==2.6.0)
#   Downloading https://download-r2.pytorch.org/whl/triton-3.2.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0) (75.2.0)
# Collecting sympy==1.13.1 (from torch==2.6.0)
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision==0.21.0) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision==0.21.0) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy==1.13.1->torch==2.6.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch==2.6.0) (3.0.3)
# Downloading https://download-r2.pytorch.org/whl/cu124/torch-2.6.0%2Bcu124-cp312-cp312-linux_x86_64.whl (768.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 768.4/768.4 MB 2.7 MB/s eta 0:00:00:00:0100:01
# Downloading https://download-r2.pytorch.org/whl/cu124/torchvision-0.21.0%2Bcu124-cp312-cp312-linux_x86_64.whl (7.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 23.5 MB/s eta 0:00:0000:0100:01
# Downloading https://download-r2.pytorch.org/whl/cu124/torchaudio-2.6.0%2Bcu124-cp312-cp312-linux_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 71.3 MB/s eta 0:00:00:00:01
# Downloading https://download.pytorch.org/whl/cu124/nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl (150.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.1/150.1 MB 6.6 MB/s eta 0:00:00:00:0100:01
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 77.0 MB/s eta 0:00:00:00:010:01
# Downloading https://download-r2.pytorch.org/whl/triton-3.2.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (166.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.7/166.7 MB 6.0 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: triton, nvidia-cusparselt-cu12, sympy, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch, torchvision, torchaudio
#   Attempting uninstall: triton
#     Found existing installation: triton 3.6.0
#     Uninstalling triton-3.6.0:
#       Successfully uninstalled triton-3.6.0
#   Attempting uninstall: nvidia-cusparselt-cu12
#     Found existing installation: nvidia-cusparselt-cu12 0.7.1
#     Uninstalling nvidia-cusparselt-cu12-0.7.1:
#       Successfully uninstalled nvidia-cusparselt-cu12-0.7.1
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.14.0
#     Uninstalling sympy-1.14.0:
#       Successfully uninstalled sympy-1.14.0
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.8.90
#     Uninstalling nvidia-nvtx-cu12-12.8.90:
#       Successfully uninstalled nvidia-nvtx-cu12-12.8.90
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.8.93
#     Uninstalling nvidia-nvjitlink-cu12-12.8.93:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.8.93
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.28.9
#     Uninstalling nvidia-nccl-cu12-2.28.9:
#       Successfully uninstalled nvidia-nccl-cu12-2.28.9
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.9.90
#     Uninstalling nvidia-curand-cu12-10.3.9.90:
#       Successfully uninstalled nvidia-curand-cu12-10.3.9.90
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.3.3.83
#     Uninstalling nvidia-cufft-cu12-11.3.3.83:
#       Successfully uninstalled nvidia-cufft-cu12-11.3.3.83
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.8.90
#     Uninstalling nvidia-cuda-runtime-cu12-12.8.90:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.8.90
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.8.93
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.8.93:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.8.93
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.8.90
#     Uninstalling nvidia-cuda-cupti-cu12-12.8.90:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.8.90
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.8.4.1
#     Uninstalling nvidia-cublas-cu12-12.8.4.1:
#       Successfully uninstalled nvidia-cublas-cu12-12.8.4.1
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.8.93
#     Uninstalling nvidia-cusparse-cu12-12.5.8.93:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.8.93
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.19.0.56
#     Uninstalling nvidia-cudnn-cu12-9.19.0.56:
#       Successfully uninstalled nvidia-cudnn-cu12-9.19.0.56
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.3.90
#     Uninstalling nvidia-cusolver-cu12-11.7.3.90:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.3.90
#   Attempting uninstall: torch
#     Found existing installation: torch 2.11.0+cu128
#     Uninstalling torch-2.11.0+cu128:
#       Successfully uninstalled torch-2.11.0+cu128
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.26.0+cu128
#     Uninstalling torchvision-0.26.0+cu128:
#       Successfully uninstalled torchvision-0.26.0+cu128
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.11.0+cu128
#     Uninstalling torchaudio-2.11.0+cu128:
#       Successfully uninstalled torchaudio-2.11.0+cu128
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-cusparselt-cu12-0.6.2 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 sympy-1.13.1 torch-2.6.0+cu124 torchaudio-2.6.0+cu124 torchvision-0.21.0+cu124 triton-3.2.0
# Requirement already satisfied: nibabel in /usr/local/lib/python3.12/dist-packages (5.4.2)
# Collecting pydicom
#   Downloading pydicom-3.0.2-py3-none-any.whl.metadata (9.4 kB)
# Collecting ipywidgets==8.1.2
#   Downloading ipywidgets-8.1.2-py3-none-any.whl.metadata (2.4 kB)
# Collecting monai[all]
#   Downloading monai-1.5.2-py3-none-any.whl.metadata (13 kB)
# Collecting comm>=0.1.3 (from ipywidgets==8.1.2)
#   Downloading comm-0.2.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: ipython>=6.1.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets==8.1.2) (7.34.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets==8.1.2) (5.7.1)
# Collecting widgetsnbextension~=4.0.10 (from ipywidgets==8.1.2)
#   Downloading widgetsnbextension-4.0.15-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in /usr/local/lib/python3.12/dist-packages (from ipywidgets==8.1.2) (3.0.16)
# Requirement already satisfied: numpy<3.0,>=1.24 in /usr/local/lib/python3.12/dist-packages (from monai[all]) (2.0.2)
# Requirement already satisfied: torch>=2.4.1 in /usr/local/lib/python3.12/dist-packages (from monai[all]) (2.6.0+cu124)
# Collecting clearml>=1.10.0rc0 (from monai[all])
#   Downloading clearml-2.1.8-py2.py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from monai[all]) (0.8.2)
# Collecting fire (from monai[all])
#   Downloading fire-0.7.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: gdown>=4.7.3 in /usr/local/lib/python3.12/dist-packages (from monai[all]) (5.2.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from monai[all]) (3.16.0)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.12/dist-packages (from monai[all]) (1.16.1)
# Collecting itk>=5.2 (from monai[all])
#   Downloading itk-5.4.6-cp311-abi3-manylinux_2_28_x86_64.whl.metadata (22 kB)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.12/dist-packages (from monai[all]) (4.26.0)
# Collecting lmdb (from monai[all])
#   Downloading lmdb-2.2.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (1.2 kB)
# Collecting lpips==0.1.4 (from monai[all])
#   Downloading lpips-0.1.4-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: matplotlib>=3.6.3 in /usr/local/lib/python3.12/dist-packages (from monai[all]) (3.10.0)
# Collecting mlflow>=2.12.2 (from monai[all])
#   Downloading mlflow-3.13.0-py3-none-any.whl.metadata (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 5.5 MB/s eta 0:00:00
# Collecting ninja (from monai[all])
#   Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: nvidia-ml-py in /usr/local/lib/python3.12/dist-packages (from monai[all]) (13.595.45)
# Collecting onnx>=1.13.0 (from monai[all])
#   Downloading onnx-1.21.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.5 kB)
# Collecting openslide-bin (from monai[all])
#   Downloading openslide_bin-4.0.0.13-py3-none-manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Collecting openslide-python (from monai[all])
#   Downloading openslide_python-1.4.3-cp311-abi3-manylinux1_x86_64.manylinux_2_5_x86_64.whl.metadata (5.0 kB)
# Collecting optuna (from monai[all])
#   Downloading optuna-4.9.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from monai[all]) (2.2.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from monai[all]) (11.3.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from monai[all]) (5.9.5)
# Collecting pyamg<5.3.0,>=5.0.0 (from monai[all])
#   Downloading pyamg-5.2.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Collecting pynrrd (from monai[all])
#   Downloading pynrrd-1.1.3-py3-none-any.whl.metadata (5.4 kB)
# Collecting pytorch-ignite==0.4.11 (from monai[all])
#   Downloading pytorch_ignite-0.4.11-py3-none-any.whl.metadata (28 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from monai[all]) (6.0.3)
# Requirement already satisfied: scikit-image>=0.14.2 in /usr/local/lib/python3.12/dist-packages (from monai[all]) (0.25.2)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.12/dist-packages (from monai[all]) (2.20.0)
# Collecting tensorboardX (from monai[all])
#   Downloading tensorboardx-2.6.5-py3-none-any.whl.metadata (6.6 kB)
# Collecting torchio (from monai[all])
#   Downloading torchio-1.2.0-py3-none-any.whl.metadata (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from monai[all]) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.47.0 in /usr/local/lib/python3.12/dist-packages (from monai[all]) (4.67.3)
# Collecting zarr (from monai[all])
#   Downloading zarr-3.2.1-py3-none-any.whl.metadata (8.7 kB)
# Collecting nni (from monai[all])
#   Downloading nni-3.0-py3-none-manylinux1_x86_64.whl.metadata (19 kB)
# Collecting imagecodecs (from monai[all])
#   Downloading imagecodecs-2026.5.10-cp312-abi3-manylinux_2_28_x86_64.whl.metadata (22 kB)
# Requirement already satisfied: tifffile in /usr/local/lib/python3.12/dist-packages (from monai[all]) (2026.4.11)
# Requirement already satisfied: scipy>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from monai[all]) (1.16.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from pytorch-ignite==0.4.11->monai[all]) (26.2)
# Requirement already satisfied: typing-extensions>=4.6 in /usr/local/lib/python3.12/dist-packages (from nibabel) (4.15.0)
# Requirement already satisfied: attrs>=18.0 in /usr/local/lib/python3.12/dist-packages (from clearml>=1.10.0rc0->monai[all]) (26.1.0)
# Collecting furl>=2.0.0 (from clearml>=1.10.0rc0->monai[all])
#   Downloading furl-2.1.4-py2.py3-none-any.whl.metadata (25 kB)
# Collecting pathlib2>=2.3.0 (from clearml>=1.10.0rc0->monai[all])
#   Downloading pathlib2-2.3.7.post1-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: pyparsing>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from clearml>=1.10.0rc0->monai[all]) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.12/dist-packages (from clearml>=1.10.0rc0->monai[all]) (2.9.0.post0)
# Requirement already satisfied: pyjwt<3.0.0,>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from clearml>=1.10.0rc0->monai[all]) (2.13.0)
# Requirement already satisfied: six>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from clearml>=1.10.0rc0->monai[all]) (1.17.0)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from clearml>=1.10.0rc0->monai[all]) (2.5.0)
# Requirement already satisfied: referencing<0.40 in /usr/local/lib/python3.12/dist-packages (from clearml>=1.10.0rc0->monai[all]) (0.37.0)
# Requirement already satisfied: requests>=2.32.0 in /usr/local/lib/python3.12/dist-packages (from clearml>=1.10.0rc0->monai[all]) (2.32.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown>=4.7.3->monai[all]) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown>=4.7.3->monai[all]) (3.29.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets==8.1.2) (75.2.0)
# Collecting jedi>=0.16 (from ipython>=6.1.0->ipywidgets==8.1.2)
#   Downloading jedi-0.20.0-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets==8.1.2) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets==8.1.2) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets==8.1.2) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets==8.1.2) (2.20.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets==8.1.2) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets==8.1.2) (0.2.2)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=6.1.0->ipywidgets==8.1.2) (4.9.0)
# Collecting itk-core==5.4.6 (from itk>=5.2->monai[all])
#   Downloading itk_core-5.4.6-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (22 kB)
# Collecting itk-numerics==5.4.6 (from itk>=5.2->monai[all])
#   Downloading itk_numerics-5.4.6-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (22 kB)
# Collecting itk-io==5.4.6 (from itk>=5.2->monai[all])
#   Downloading itk_io-5.4.6-cp311-abi3-manylinux_2_28_x86_64.whl.metadata (22 kB)
# Collecting itk-filtering==5.4.6 (from itk>=5.2->monai[all])
#   Downloading itk_filtering-5.4.6-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (22 kB)
# Collecting itk-registration==5.4.6 (from itk>=5.2->monai[all])
#   Downloading itk_registration-5.4.6-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (22 kB)
# Collecting itk-segmentation==5.4.6 (from itk>=5.2->monai[all])
#   Downloading itk_segmentation-5.4.6-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (22 kB)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema->monai[all]) (2025.9.1)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema->monai[all]) (0.30.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.3->monai[all]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.3->monai[all]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.3->monai[all]) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.3->monai[all]) (1.5.0)
# Collecting mlflow-skinny==3.13.0 (from mlflow>=2.12.2->monai[all])
#   Downloading mlflow_skinny-3.13.0-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 5.2 MB/s eta 0:00:00
# Collecting mlflow-tracing==3.13.0 (from mlflow>=2.12.2->monai[all])
#   Downloading mlflow_tracing-3.13.0-py3-none-any.whl.metadata (19 kB)
# Collecting Flask-CORS<7 (from mlflow>=2.12.2->monai[all])
#   Downloading flask_cors-6.0.2-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: Flask<4 in /usr/local/lib/python3.12/dist-packages (from mlflow>=2.12.2->monai[all]) (3.1.3)
# Requirement already satisfied: aiohttp<4 in /usr/local/lib/python3.12/dist-packages (from mlflow>=2.12.2->monai[all]) (3.13.5)
# Requirement already satisfied: alembic!=1.10.0,<2 in /usr/local/lib/python3.12/dist-packages (from mlflow>=2.12.2->monai[all]) (1.18.4)
# Requirement already satisfied: cryptography<49,>=43.0.0 in /usr/local/lib/python3.12/dist-packages (from mlflow>=2.12.2->monai[all]) (48.0.0)
# Collecting docker<8,>=4.0.0 (from mlflow>=2.12.2->monai[all])
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting graphene<4 (from mlflow>=2.12.2->monai[all])
#   Downloading graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting gunicorn<27 (from mlflow>=2.12.2->monai[all])
#   Downloading gunicorn-26.0.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting huey<4,>=2.5.4 (from mlflow>=2.12.2->monai[all])
#   Downloading huey-3.0.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: pyarrow<25,>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from mlflow>=2.12.2->monai[all]) (18.1.0)
# Requirement already satisfied: scikit-learn<2 in /usr/local/lib/python3.12/dist-packages (from mlflow>=2.12.2->monai[all]) (1.6.1)
# Collecting skops<1 (from mlflow>=2.12.2->monai[all])
#   Downloading skops-0.14.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from mlflow>=2.12.2->monai[all]) (2.0.49)
# Requirement already satisfied: cachetools<8,>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.13.0->mlflow>=2.12.2->monai[all]) (6.2.6)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.13.0->mlflow>=2.12.2->monai[all]) (8.4.0)
# Requirement already satisfied: cloudpickle<4 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.13.0->mlflow>=2.12.2->monai[all]) (3.1.2)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==3.13.0->mlflow>=2.12.2->monai[all])
#   Downloading databricks_sdk-0.113.0-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: fastapi<1 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.13.0->mlflow>=2.12.2->monai[all]) (0.136.1)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.13.0->mlflow>=2.12.2->monai[all]) (3.1.50)
# Requirement already satisfied: importlib_metadata!=4.7.0,<10,>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.13.0->mlflow>=2.12.2->monai[all]) (8.7.1)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.13.0->mlflow>=2.12.2->monai[all]) (1.38.0)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.13.0->mlflow>=2.12.2->monai[all]) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.13.0->mlflow>=2.12.2->monai[all]) (1.38.0)
# Requirement already satisfied: protobuf<8,>=3.12.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.13.0->mlflow>=2.12.2->monai[all]) (5.29.6)
# Requirement already satisfied: pydantic<3,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.13.0->mlflow>=2.12.2->monai[all]) (2.12.3)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.13.0->mlflow>=2.12.2->monai[all]) (1.2.2)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.13.0->mlflow>=2.12.2->monai[all]) (0.5.5)
# Requirement already satisfied: starlette<2 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.13.0->mlflow>=2.12.2->monai[all]) (0.52.1)
# Requirement already satisfied: uvicorn<1 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.13.0->mlflow>=2.12.2->monai[all]) (0.47.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from onnx>=1.13.0->monai[all]) (0.5.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->monai[all]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->monai[all]) (2026.2)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.14.2->monai[all]) (3.6.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.14.2->monai[all]) (2.37.3)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.14.2->monai[all]) (0.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai[all]) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai[all]) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai[all]) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai[all]) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai[all]) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai[all]) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai[all]) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai[all]) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai[all]) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai[all]) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai[all]) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai[all]) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai[all]) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai[all]) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai[all]) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai[all]) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai[all]) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy==1.13.1->torch>=2.4.1->monai[all]) (1.3.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from fire->monai[all]) (3.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->monai[all]) (1.5.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->monai[all]) (0.28.1)
# Requirement already satisfied: typer>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->monai[all]) (0.25.1)
# Collecting numpy<3.0,>=1.24 (from monai[all])
#   Downloading numpy-2.4.6-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Collecting astor (from nni->monai[all])
#   Downloading astor-0.8.1-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting colorama (from nni->monai[all])
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting filelock (from gdown>=4.7.3->monai[all])
#   Downloading filelock-3.11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting json-tricks>=3.15.5 (from nni->monai[all])
#   Downloading json_tricks-3.17.3-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.12/dist-packages (from nni->monai[all]) (3.17.0)
# Collecting PythonWebHDFS (from nni->monai[all])
#   Downloading PythonWebHDFS-0.2.3-py3-none-any.whl.metadata (717 bytes)
# Collecting responses (from nni->monai[all])
#   Downloading responses-0.26.1-py3-none-any.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 kB 5.8 MB/s eta 0:00:00
# Collecting schema (from nni->monai[all])
#   Downloading schema-0.7.8-py2.py3-none-any.whl.metadata (34 kB)
# Collecting typeguard<4.1.3,>=3.0.0 (from nni->monai[all])
#   Downloading typeguard-4.1.2-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: websockets>=10.1 in /usr/local/lib/python3.12/dist-packages (from nni->monai[all]) (15.0.1)
# Collecting colorlog (from optuna->monai[all])
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard->monai[all]) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard->monai[all]) (1.80.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard->monai[all]) (3.10.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard->monai[all]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard->monai[all]) (3.1.8)
# Collecting deprecated>=1.2 (from torchio->monai[all])
#   Downloading deprecated-1.3.1-py2.py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: humanize>=0.1 in /usr/local/lib/python3.12/dist-packages (from torchio->monai[all]) (4.15.0)
# Collecting jaxtyping>=0.2 (from torchio->monai[all])
#   Downloading jaxtyping-0.3.10-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: rich>=10 in /usr/local/lib/python3.12/dist-packages (from torchio->monai[all]) (13.9.4)
# Collecting simpleitk!=2.0.*,!=2.1.1.1,>=1.3 (from torchio->monai[all])
#   Downloading simpleitk-2.5.5-cp311-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (7.4 kB)
# Collecting donfig>=0.8 (from zarr->monai[all])
#   Downloading donfig-0.8.1.post1-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: google-crc32c>=1.5 in /usr/local/lib/python3.12/dist-packages (from zarr->monai[all]) (1.8.0)
# Collecting numcodecs>=0.14 (from zarr->monai[all])
#   Downloading numcodecs-0.16.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4->mlflow>=2.12.2->monai[all]) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4->mlflow>=2.12.2->monai[all]) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4->mlflow>=2.12.2->monai[all]) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4->mlflow>=2.12.2->monai[all]) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4->mlflow>=2.12.2->monai[all]) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4->mlflow>=2.12.2->monai[all]) (1.24.2)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic!=1.10.0,<2->mlflow>=2.12.2->monai[all]) (1.3.12)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from cryptography<49,>=43.0.0->mlflow>=2.12.2->monai[all]) (2.0.0)
# Requirement already satisfied: wrapt<3,>=1.10 in /usr/local/lib/python3.12/dist-packages (from deprecated>=1.2->torchio->monai[all]) (2.2.0)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from Flask<4->mlflow>=2.12.2->monai[all]) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from Flask<4->mlflow>=2.12.2->monai[all]) (2.2.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from Flask<4->mlflow>=2.12.2->monai[all]) (3.0.3)
# Collecting orderedmultidict>=1.0.1 (from furl>=2.0.0->clearml>=1.10.0rc0->monai[all])
#   Downloading orderedmultidict-1.0.2-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow>=2.12.2->monai[all])
#   Downloading graphql_core-3.2.8-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow>=2.12.2->monai[all])
#   Downloading graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub->monai[all]) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub->monai[all]) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub->monai[all]) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub->monai[all]) (3.15)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub->monai[all]) (0.16.0)
# Collecting wadler-lindig>=0.1.3 (from jaxtyping>=0.2->torchio->monai[all])
#   Downloading wadler_lindig-0.1.7-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets==8.1.2) (0.8.7)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets==8.1.2) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.1.0->ipywidgets==8.1.2) (0.7.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.0->clearml>=1.10.0rc0->monai[all]) (3.4.7)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10->torchio->monai[all]) (4.2.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<2->mlflow>=2.12.2->monai[all]) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<2->mlflow>=2.12.2->monai[all]) (3.6.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy<3,>=1.4.0->mlflow>=2.12.2->monai[all]) (3.5.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.20.0->huggingface-hub->monai[all]) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer>=0.20.0->huggingface-hub->monai[all]) (0.0.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown>=4.7.3->monai[all]) (2.8.3)
# Requirement already satisfied: simplejson in /usr/local/lib/python3.12/dist-packages (from PythonWebHDFS->nni->monai[all]) (4.1.1)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown>=4.7.3->monai[all]) (1.7.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=2.0.0->cryptography<49,>=43.0.0->mlflow>=2.12.2->monai[all]) (3.0)
# Requirement already satisfied: google-auth~=2.0 in /usr/local/lib/python3.12/dist-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.13.0->mlflow>=2.12.2->monai[all]) (2.47.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1->mlflow-skinny==3.13.0->mlflow>=2.12.2->monai[all]) (0.4.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.13.0->mlflow>=2.12.2->monai[all]) (4.0.12)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib_metadata!=4.7.0,<10,>=3.7.0->mlflow-skinny==3.13.0->mlflow>=2.12.2->monai[all]) (4.1.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10->torchio->monai[all]) (0.1.2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.13.0->mlflow>=2.12.2->monai[all]) (0.59b0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.13.0->mlflow>=2.12.2->monai[all]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.13.0->mlflow>=2.12.2->monai[all]) (2.41.4)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.13.0->mlflow>=2.12.2->monai[all]) (5.0.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.13.0->mlflow>=2.12.2->monai[all]) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.13.0->mlflow>=2.12.2->monai[all]) (4.9.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.13.0->mlflow>=2.12.2->monai[all]) (0.6.3)
# Downloading ipywidgets-8.1.2-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.4/139.4 kB 9.6 MB/s eta 0:00:00
# Downloading lpips-0.1.4-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 5.9 MB/s eta 0:00:00
# Downloading pytorch_ignite-0.4.11-py3-none-any.whl (266 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.5/266.5 kB 18.1 MB/s eta 0:00:00
# Downloading pydicom-3.0.2-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 89.6 MB/s eta 0:00:00
# Downloading clearml-2.1.8-py2.py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 75.0 MB/s eta 0:00:00
# Downloading comm-0.2.3-py3-none-any.whl (7.3 kB)
# Downloading itk-5.4.6-cp311-abi3-manylinux_2_28_x86_64.whl (16 kB)
# Downloading itk_core-5.4.6-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (81.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 MB 12.3 MB/s eta 0:00:0000:01:00:01
# Downloading itk_filtering-5.4.6-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (67.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 MB 11.8 MB/s eta 0:00:00:00:0100:01
# Downloading itk_io-5.4.6-cp311-abi3-manylinux_2_28_x86_64.whl (28.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.0/28.0 MB 69.4 MB/s eta 0:00:00:00:0100:01
# Downloading itk_numerics-5.4.6-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (57.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.2/57.2 MB 11.9 MB/s eta 0:00:0000:0100:01m
# Downloading itk_registration-5.4.6-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (28.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.5/28.5 MB 67.6 MB/s eta 0:00:00:00:0100:01
# Downloading itk_segmentation-5.4.6-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (15.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 89.8 MB/s eta 0:00:00:00:0100:01
# Downloading mlflow-3.13.0-py3-none-any.whl (10.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 118.0 MB/s eta 0:00:0000:010:01
# Downloading mlflow_skinny-3.13.0-py3-none-any.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 118.2 MB/s eta 0:00:00
# Downloading mlflow_tracing-3.13.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 84.3 MB/s eta 0:00:00
# Downloading onnx-1.21.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (17.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 100.2 MB/s eta 0:00:0000:0100:01
# Downloading pyamg-5.2.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 87.6 MB/s eta 0:00:00
# Downloading widgetsnbextension-4.0.15-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 103.5 MB/s eta 0:00:00
# Downloading fire-0.7.1-py3-none-any.whl (115 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 13.1 MB/s eta 0:00:00
# Downloading imagecodecs-2026.5.10-cp312-abi3-manylinux_2_28_x86_64.whl (27.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.8/27.8 MB 15.2 MB/s eta 0:00:00:00:0100:01
# Downloading numpy-2.4.6-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 93.2 MB/s eta 0:00:00:00:0100:01
# Downloading lmdb-2.2.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (333 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 333.1/333.1 kB 30.7 MB/s eta 0:00:00
# Downloading monai-1.5.2-py3-none-any.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 90.3 MB/s eta 0:00:00
# Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (180 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 20.2 MB/s eta 0:00:00
# Downloading nni-3.0-py3-none-manylinux1_x86_64.whl (61.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 MB 11.2 MB/s eta 0:00:0000:01:00:01
# Downloading openslide_bin-4.0.0.13-py3-none-manylinux_2_28_x86_64.whl (4.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 84.4 MB/s eta 0:00:00:00:01
# Downloading openslide_python-1.4.3-cp311-abi3-manylinux1_x86_64.manylinux_2_5_x86_64.whl (36 kB)
# Downloading optuna-4.9.0-py3-none-any.whl (425 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 425.6/425.6 kB 36.5 MB/s eta 0:00:00
# Downloading pynrrd-1.1.3-py3-none-any.whl (23 kB)
# Downloading tensorboardx-2.6.5-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 10.0 MB/s eta 0:00:00
# Downloading torchio-1.2.0-py3-none-any.whl (202 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.1/202.1 kB 21.3 MB/s eta 0:00:00
# Downloading zarr-3.2.1-py3-none-any.whl (319 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.6/319.6 kB 31.7 MB/s eta 0:00:00
# Downloading deprecated-1.3.1-py2.py3-none-any.whl (11 kB)
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 17.4 MB/s eta 0:00:00
# Downloading donfig-0.8.1.post1-py3-none-any.whl (21 kB)
# Downloading filelock-3.11.0-py3-none-any.whl (10.0 kB)
# Downloading flask_cors-6.0.2-py3-none-any.whl (13 kB)
# Downloading furl-2.1.4-py2.py3-none-any.whl (27 kB)
# Downloading graphene-3.4.3-py2.py3-none-any.whl (114 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 13.9 MB/s eta 0:00:00
# Downloading gunicorn-26.0.0-py3-none-any.whl (212 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.0/212.0 kB 23.4 MB/s eta 0:00:00
# Downloading huey-3.0.1-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.3/86.3 kB 10.4 MB/s eta 0:00:00
# Downloading jaxtyping-0.3.10-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.4/56.4 kB 6.8 MB/s eta 0:00:00
# Downloading jedi-0.20.0-py2.py3-none-any.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 87.1 MB/s eta 0:00:00:00:01
# Downloading json_tricks-3.17.3-py2.py3-none-any.whl (27 kB)
# Downloading numcodecs-0.16.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (9.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 89.8 MB/s eta 0:00:00:00:0100:01
# Downloading pathlib2-2.3.7.post1-py2.py3-none-any.whl (18 kB)
# Downloading simpleitk-2.5.5-cp311-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (52.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 MB 13.3 MB/s eta 0:00:00:00:0100:01
# Downloading skops-0.14.0-py3-none-any.whl (132 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.2/132.2 kB 14.3 MB/s eta 0:00:00
# Downloading typeguard-4.1.2-py3-none-any.whl (33 kB)
# Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Downloading PythonWebHDFS-0.2.3-py3-none-any.whl (10 kB)
# Downloading responses-0.26.1-py3-none-any.whl (35 kB)
# Downloading schema-0.7.8-py2.py3-none-any.whl (19 kB)
# Downloading databricks_sdk-0.113.0-py3-none-any.whl (906 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 907.0/907.0 kB 71.9 MB/s eta 0:00:00
# Downloading graphql_core-3.2.8-py3-none-any.whl (207 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 23.7 MB/s eta 0:00:00
# Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Downloading orderedmultidict-1.0.2-py2.py3-none-any.whl (11 kB)
# Downloading wadler_lindig-0.1.7-py3-none-any.whl (20 kB)
# Installing collected packages: simpleitk, schema, json-tricks, huey, widgetsnbextension, wadler-lindig, typeguard, pydicom, pathlib2, orderedmultidict, openslide-python, openslide-bin, numpy, ninja, lmdb, jedi, gunicorn, graphql-core, fire, filelock, donfig, deprecated, comm, colorlog, colorama, astor, tensorboardX, responses, PythonWebHDFS, pynrrd, numcodecs, jaxtyping, itk-core, imagecodecs, graphql-relay, furl, docker, zarr, pyamg, optuna, onnx, itk-numerics, itk-io, ipywidgets, graphene, Flask-CORS, databricks-sdk, torchio, skops, pytorch-ignite, nni, monai, itk-filtering, clearml, mlflow-tracing, mlflow-skinny, lpips, itk-segmentation, itk-registration, mlflow, itk
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.10
#     Uninstalling widgetsnbextension-3.6.10:
#       Successfully uninstalled widgetsnbextension-3.6.10
#   Attempting uninstall: typeguard
#     Found existing installation: typeguard 4.5.2
#     Uninstalling typeguard-4.5.2:
#       Successfully uninstalled typeguard-4.5.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.29.0
#     Uninstalling filelock-3.29.0:
#       Successfully uninstalled filelock-3.29.0
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.1
#     Uninstalling ipywidgets-7.7.1:
#       Successfully uninstalled ipywidgets-7.7.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.4.6 which is incompatible.
# pytensor 2.38.3 requires filelock>=3.15, but you have filelock 3.11.0 which is incompatible.
# Successfully installed Flask-CORS-6.0.2 PythonWebHDFS-0.2.3 astor-0.8.1 clearml-2.1.8 colorama-0.4.6 colorlog-6.10.1 comm-0.2.3 databricks-sdk-0.113.0 deprecated-1.3.1 docker-7.1.0 donfig-0.8.1.post1 filelock-3.11.0 fire-0.7.1 furl-2.1.4 graphene-3.4.3 graphql-core-3.2.8 graphql-relay-3.2.0 gunicorn-26.0.0 huey-3.0.1 imagecodecs-2026.5.10 ipywidgets-8.1.2 itk-5.4.6 itk-core-5.4.6 itk-filtering-5.4.6 itk-io-5.4.6 itk-numerics-5.4.6 itk-registration-5.4.6 itk-segmentation-5.4.6 jaxtyping-0.3.10 jedi-0.20.0 json-tricks-3.17.3 lmdb-2.2.0 lpips-0.1.4 mlflow-3.13.0 mlflow-skinny-3.13.0 mlflow-tracing-3.13.0 monai-1.5.2 ninja-1.13.0 nni-3.0 numcodecs-0.16.5 numpy-2.4.6 onnx-1.21.0 openslide-bin-4.0.0.13 openslide-python-1.4.3 optuna-4.9.0 orderedmultidict-1.0.2 pathlib2-2.3.7.post1 pyamg-5.2.1 pydicom-3.0.2 pynrrd-1.1.3 pytorch-ignite-0.4.11 responses-0.26.1 schema-0.7.8 simpleitk-2.5.5 skops-0.14.0 tensorboardX-2.6.5 torchio-1.2.0 typeguard-4.1.2 wadler-lindig-0.1.7 widgetsnbextension-4.0.15 zarr-3.2.1
# Cloning into 'tutorials'...
# remote: Enumerating objects: 8673, done.
# remote: Counting objects: 100% (581/581), done.
# remote: Compressing objects: 100% (414/414), done.
# remote: Total 8673 (delta 412), reused 167 (delta 167), pack-reused 8092 (from 3)
# Receiving objects: 100% (8673/8673), 330.55 MiB | 32.97 MiB/s, done.
# Resolving deltas: 100% (5132/5132), done.
# Cloning into 'MONAIBootcamp2021'...
# remote: Enumerating objects: 133, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 133 (delta 22), reused 15 (delta 15), pack-reused 105 (from 1)
# Receiving objects: 100% (133/133), 86.93 MiB | 35.41 MiB/s, done.
# Resolving deltas: 100% (50/50), done.
# GPU Avalable: True
# GPU type: Tesla T4

# %%
# Optional:
# if you are using google colab, the server would clean all the data after you disconnect. 
# So, you may like to save the data in your personal space.
# One of the solution is mount Google Drive to persist trained model weights and logs

drive.mount('/content/drive/') # link to google drive

PROJECT_SANDBOX = "/content/drive/MyDrive/Colab_Workspace/MONAI_LISA" # link to specific working directory

print('Current Dir:')
print(os.listdir(PROJECT_SANDBOX)) # check the list
# Out:
# Mounted at /content/drive/
# Current Dir:
# []

# %%
# !nvidia-smi
# Out:
# Mon Jun  1 20:31:32 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   31C    P8              9W /   70W |       3MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# # Understanding MONAI Datasets, Caching, and Networks
# ---

# %% [markdown]
# <img src="monai.png" style="width: 700px;"/>
#
# Welcome to the MONAI bootcamp! This notebook will introduce you to the MONAI Caching, Datasets and Network options, and then hands-on  and architecture, and then hands-on with implmenting SmartCache on a test dataset.

# %% [markdown]
# Users often need to train the model with many (potentially thousands of) epochs over the data to achieve the desired model quality. A native PyTorch implementation may repeatedly load data and run the same preprocessing steps for every epoch during training, which can be time-consuming and unnecessary, especially when the medical image volumes are large.  By utilizing Dataset Caching, you can reduce the amount of time your system takes to load this data and preprocess it, reducing your overall training time.
#
# Network functionality represents a significant design opportunity for MONAI. Pytorch is very much unopinionated in how networks are defined. It provides Module as a base class to create a network and a few methods that must be implemented. Still, there is no prescribed pattern nor much helper functionality for initializing networks.
#
# The lack of helper functionality leaves a lot of room for defining some beneficial 'best practice' patterns for constructing new networks in MONAI. Although trivial, inflexible network implementations are easy enough, but we can give users a toolset that makes it much easier to build well-engineered, flexible networks and demonstrate their value by committing to use them in the networks that we build.
#
# ## MONAI Datasets, Caching, and Networks
#
# To help you understand more about MONAI Datasets and Caching options, this guide will help you answer five key questions:
#
# 1. **What is a MONAI Dataset?**
# 2. **What is Dataset Caching and how do I use it?**
# 3. **What common datasets are provided by MONAI?**
# 4. **What Network and Network components does MONAI provide?**
# 5. **How do you use MONAI Layers?**
# 6. **How do you use these flexible layers to create a network?**
# 7. **Which Networks are included with MONAI?**

# %% [markdown]
# Let's get started by importing our dependencies.

# %%
import time
import torch
import os
import monai
from monai.config import print_config
from monai.data import Dataset, DataLoader, CacheDataset, PersistentDataset, SmartCacheDataset
from monai.apps import DecathlonDataset
from monai.transforms import (
    MapTransform,
)

print_config()
# Out:
# <frozen importlib._bootstrap_external>:1301: FutureWarning: The cuda.cudart module is deprecated and will be removed in a future release, please switch to use the cuda.bindings.runtime module instead.
# MONAI version: 1.5.2
# Numpy version: 2.0.2
# Pytorch version: 2.6.0+cu124
# MONAI flags: HAS_EXT = False, USE_COMPILED = False, USE_META_DICT = False
# MONAI rev id: d18565fb3e4fd8c556707f91ac280a2dc3f681c1
# MONAI __file__: /usr/local/lib/python3.12/dist-packages/monai/__init__.py
#
# Optional dependencies:
# Pytorch Ignite version: 0.4.11
# ITK version: 5.4.6
# Nibabel version: 5.4.2
# scikit-image version: 0.25.2
# scipy version: 1.16.3
# Pillow version: 11.3.0
# Tensorboard version: 2.20.0
# gdown version: 5.2.2
# TorchVision version: 0.21.0+cu124
# tqdm version: 4.67.3
# lmdb version: 2.2.0
# psutil version: 5.9.5
# pandas version: 2.2.2
# einops version: 0.8.2
# transformers version: 5.0.0
# mlflow version: NOT INSTALLED or UNKNOWN VERSION.
# pynrrd version: 1.1.3
# clearml version: NOT INSTALLED or UNKNOWN VERSION.
#
# For details about installing the optional dependencies, please visit:
#     https://docs.monai.io/en/latest/installation.html#installing-the-recommended-dependencies

# %% [markdown]
# ## **1. What is a MONAI Dataset?**

# %% [markdown]
# A MONAI Dataset is a generic dataset with a __len__ property, __getitem__ property, and an optional callable data transform when fetching a data sample.
#
# We'll start by initializing some generic data, calling the Dataset class with the generic data, and specifying None for our transforms.

# %%
items = [{"data": 4}, 
         {"data": 9}, 
         {"data": 3}, 
         {"data": 7}, 
         {"data": 1},
         {"data": 2},
         {"data": 5}]
dataset = monai.data.Dataset(items, transform=None)

print(f"Length of dataset is {len(dataset)}")
for item in dataset:
    print(item)
# Out:
# Length of dataset is 7
# {'data': 4}
# {'data': 9}
# {'data': 3}
# {'data': 7}
# {'data': 1}
# {'data': 2}
# {'data': 5}

# %% [markdown]
# #### Compatible with the PyTorch DataLoader
#
# MONAI functionality should be compatible with the PyTorch DataLoader, although free to subclass from it if there is additional functionality that we consider key, which cannot be realized with the standard DataLoader class.

# %%
for item in torch.utils.data.DataLoader(dataset, batch_size=2):
    print(item)
# Out:
# {'data': tensor([4, 9])}
# {'data': tensor([3, 7])}
# {'data': tensor([1, 2])}
# {'data': tensor([5])}

# %% [markdown]
# ### Load items with a customized transform
#
# We'll create a custom transform called `SquareIt`, which will replace the corresponding value of the input's `keys` with a squared value. In our case, `SquareIt(keys='data')` will apply the square transform to the value of `x['data']`.

# %%
class SquareIt(MapTransform):
    def __init__(self, keys):
        MapTransform.__init__(self, keys)
        print(f"keys to square it: {self.keys}")
        
    def __call__(self, x):
        key = self.keys[0]
        data = x[key]
        output = {key: data ** 2}
        return output

square_dataset = Dataset(items, transform=SquareIt(keys='data'))
for item in square_dataset:
    print(item)
# Out:
# keys to square it: ('data',)
# {'data': 16}
# {'data': 81}
# {'data': 9}
# {'data': 49}
# {'data': 1}
# {'data': 4}
# {'data': 25}

# %% [markdown]
# ## **2. What is Dataset Caching and how do I use it?**
#
#  MONAI provides multi-thread versions of `CacheDataset` and `LMDBDataset` to accelerate these transformation steps during training by storing the intermediate outcomes before the first randomized transform in the transform chain. Enabling this feature could potentially give 10x training speedups in the Datasets experiment.
#
# <img src="cache_dataset.png" style="width: 700px;"/>
#
# To demonstrate the benefit dataset caching, we're going to construct a dataset with a slow transform.  To do that, we're going to call the sleep function during each of the `__call__` functions.

# %%
class SlowSquare(MapTransform):
    def __init__(self, keys):
        MapTransform.__init__(self, keys)
        print(f"keys to square it: {self.keys}")

    def __call__(self, x):
        time.sleep(1.0)
        output = {key: x[key] ** 2 for key in self.keys}
        return output

square_dataset = Dataset(items, transform=SlowSquare(keys='data'))
# Out:
# keys to square it: ('data',)

# %% [markdown]
# As expected, it's going to take about 7 seconds to go through all the items.

# %%
# %time for item in square_dataset: print(item)
# Out:
# {'data': 16}
# {'data': 81}
# {'data': 9}
# {'data': 49}
# {'data': 1}
# {'data': 4}
# {'data': 25}
# CPU times: user 5.63 ms, sys: 2.11 ms, total: 7.74 ms
# Wall time: 7 s

# %% [markdown]
# Every time we run this loop we're going to get roughly 7 seconds to go through all of the items.  If you were do this for 100 epochs, you're adding almost 12 extra minutes of load time to your total training loop.  Let's look at ways that we can improve this time by utilizing caching.

# %% [markdown]
# ### Cache Dataset
#
# When using [CacheDataset](https://docs.monai.io/en/latest/data.html?highlight=dataset#cachedataset) the caching is done when the object is initialized for the first time, so the initialization is slower than a regular dataset.
#
# By caching the results of non-random preprocessing transforms, it accelerates the training data pipeline. If the requested data is not in the cache, all transforms will run normally.

# %%
# %time square_cached = CacheDataset(items, transform=SlowSquare(keys='data'))
# Out:
# keys to square it: ('data',)
# Loading dataset: 100%|██████████| 7/7 [00:07<00:00,  1.00s/it]
# CPU times: user 17.3 ms, sys: 3.89 ms, total: 21.2 ms
# Wall time: 7.01 s

# %% [markdown]
# However, repeatedly fetching the items from an initialized CacheDataset is fast.

# %%
# %timeit list(item for item in square_cached)
# Out:
# 12.4 µs ± 3.43 µs per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %% [markdown]
# ### Persistent Caching
#
# [PersistentDataset](https://docs.monai.io/en/latest/data.html?highlight=dataset#persistentdataset) allows for persistent storage of pre-computed values to efficiently manage larger than memory dictionary format data.
#
# The non-random transform components are computed when first used and stored in the cache_dir for rapid retrieval on subsequent uses.

# %%
square_persist = monai.data.PersistentDataset(items, transform=SlowSquare(keys='data'), cache_dir="my_cache")
# Out:
# keys to square it: ('data',)

# %%
# %time for item in square_persist: print(item)
# Out:
# {'data': 16}
# {'data': 81}
# {'data': 9}
# {'data': 49}
# {'data': 1}
# {'data': 4}
# {'data': 25}
# CPU times: user 15.6 ms, sys: 0 ns, total: 15.6 ms
# Wall time: 7.01 s

# %% [markdown]
# During the initialization of the PersistentDataset we passed in the parameter "my_cache" for the location to store the intermediate data. We'll look at that directory below.

# %%
# !ls my_cache
# Out:
# 57d3e1f66415b9a6a36a90dd89c708c3.pt  acdbabea1a1facbf07dbe5010a951af9.pt
# 5ec8e24ba3963d83f2f6c81744796545.pt  ca0b3885ae71075716d5bd863961a8bc.pt
# 6c81bd5aa312ecd4ba9a5e0340e06a55.pt  f263a1a8f1344ac65b574f0bf30813af.pt
# 71177f0b196d6c5f84f26579bf19caae.pt

# %% [markdown]
# When calling out to the dataset on the following epochs, it will not call the slow transform but used the cached data.

# %%
# %timeit [item for item in square_persist] 

# the speed is slower than using cachedataset, but persistent cacheing requires less RAM.
# Out:
# 1.35 ms ± 148 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [markdown]
# Fresh dataset instances can make use of the caching data:

# %%
square_persist_1 = monai.data.PersistentDataset(items, transform=SlowSquare(keys='data'), cache_dir="my_cache")
# %timeit [item for item in square_persist_1]

# persistentDataset use the hash code of the data filename as the link. 
# So if you change the deterministic transform, 
# you should use another another cache_dir or clean the cache_dir.
# Out:
# keys to square it: ('data',)
# 1.92 ms ± 143 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# #### Caching in action
# - There's also a [SmartCacheDataset](https://docs.monai.io/en/latest/data.html#monai.data.SmartCacheDataset) to hide the transforms latency with less memory consumption.
# - The dataset tutorial notebook has a working example and a comparison of different caching mechanism in MONAI: https://github.com/Project-MONAI/tutorials/blob/master/acceleration/dataset_type_performance.ipynb

# %% [markdown]
# <img src="datasets_speed.png" style="width: 700px;"/>

# %% [markdown]
# ## **3. What common datasets are provided by MONAI?**

# %% [markdown]
# To quickly get started with popular training data in the medical domain, MONAI provides several data-specific Datasets(like: MedNISTDataset, DecathlonDataset, etc.), which include downloading from our AWS storage, extracting data files and support generation of training/evaluation items with transforms.
#
# The [DecathlonDataset](https://docs.monai.io/en/latest/data.html?highlight=dataset#decathlon-datalist) function leverages the features described throughout this notebook.  These datasets are an extension of CacheDataset covered above.

# %%
dataset = monai.apps.DecathlonDataset(root_dir=os.path.abspath("./"), task="Task09_Spleen", section="training", download=True)
# Out:
# Task09_Spleen.tar: 1.50GB [01:58, 13.6MB/s]
# 2026-06-01 20:34:39,982 - INFO - Downloaded: /content/Task09_Spleen.tar
# 2026-06-01 20:34:42,908 - INFO - Verified 'Task09_Spleen.tar', md5: 410d4a301da4e5b2f6f86ec3ddba524e.
# 2026-06-01 20:34:42,909 - INFO - Writing into directory: /content.
# Loading dataset: 100%|██████████| 33/33 [00:45<00:00,  1.37s/it]

# %%
print(dataset.get_properties("numTraining"))
print(dataset.get_properties("description"))
# Out:
# {'numTraining': 41}
# {'description': 'Spleen Segmentation'}

# %%
print(dataset[0]['image'].shape)
print(dataset[0]['label'].shape)
# Out:
# torch.Size([512, 512, 55])
# torch.Size([512, 512, 55])

# %%
import matplotlib.pyplot as plt
import numpy as np

im_spleen = dataset[0]['image'][:,:,20]
im_label = dataset[0]['label'][:,:,31]

print(np.unique(im_label.view(-1)))

img_min = np.min(im_spleen)
img_max = np.max(im_spleen)

im_spleen_norm = (im_spleen-img_min)/(img_max-img_min)

plt.imshow(np.hstack(( im_spleen_norm , im_label)))
# Out:
# [0. 1.]

# %% [markdown]
# ## 4. **What Network and Network components does MONAI provide?**

# %% [markdown]
# MONAI provides definitions for networks and their components that inherit directly from Pytorch Module, Sequential, etc. These general purpose networks include parameterized topologies that can easily be expanded are independent from rest of MONAI so networks can be used with existing training code.
#
# MONAI includes the following submodules:
# - layers: defines low level layers, factories for selecting Pytorch and custom layers based on dimension and other arguments
# - blocks: mid-level building blocks defining specific reusable concepts networks are constructed from
# - nets: full network definitions for common architectures, eg. UNet, VNet, Densenet,
#
# Blocks and networks use LayerFactory objects as generic factory for custom and PyTorch layers.
#
# MONAI provides blocks for defining:
# - Convolution with activation and regularization
# - Residual units
# - Squeeze/excitation
# - Downsampling/upsampling
# - Subpixel convolutions

# %% [markdown]
# ### How do you use MONAI Layers?

# %%
from monai.networks.layers import Conv, Act, split_args, Pool

# %% [markdown]
# ### Convolution as an example
#
# The [Conv](https://docs.monai.io/en/latest/networks.html#convolution) class has two options for the first argument. The second argument must be the number of spatial dimensions, `Conv[name, dimension]`, for example:

# %%
print(Conv[Conv.CONV, 1])
print(Conv[Conv.CONV, 2])
print(Conv[Conv.CONV, 3])
print(Conv[Conv.CONVTRANS, 1])
print(Conv[Conv.CONVTRANS, 2])
print(Conv[Conv.CONVTRANS, 3])
# Out:
# <class 'torch.nn.modules.conv.Conv1d'>
# <class 'torch.nn.modules.conv.Conv2d'>
# <class 'torch.nn.modules.conv.Conv3d'>
# <class 'torch.nn.modules.conv.ConvTranspose1d'>
# <class 'torch.nn.modules.conv.ConvTranspose2d'>
# <class 'torch.nn.modules.conv.ConvTranspose3d'>

# %% [markdown]
# The configured classes are the "vanilla" PyTorch layers. We could create instances of them by specifying the layer arguments:

# %%
print(Conv[Conv.CONV, 2](in_channels=1, out_channels=4, kernel_size=3))
print(Conv[Conv.CONV, 3](in_channels=1, out_channels=4, kernel_size=3))
# Out:
# Conv2d(1, 4, kernel_size=(3, 3), stride=(1, 1))
# Conv3d(1, 4, kernel_size=(3, 3, 3), stride=(1, 1, 1))

# %% [markdown]
# The [Act](https://docs.monai.io/en/latest/networks.html#module-monai.networks.layers.Act) classes don't require the spatial dimension information, but supports additional arguments.

# %%
print(Act[Act.PRELU])
Act[Act.PRELU](num_parameters=1, init=0.1)
# Out:
# <class 'torch.nn.modules.activation.PReLU'>
# PReLU(num_parameters=1)

# %% [markdown]
# These could be fully specified with a tuple of `(type_name, arg_dict)`, such as `("prelu", {"num_parameters": 1, "init": 0.1})`:

# %%
act_name, act_args = split_args(("prelu", {"num_parameters": 1, "init": 0.1}))
Act[act_name](**act_args)
# Out:
# PReLU(num_parameters=1)

# %% [markdown]
# ## **5. How do you use these components to create a network?**

# %% [markdown]
# ### Flexible Definition Networks
#
# These APIs allow for flexible definitions of networks.  Below we'll create a class called `MyNetwork` that utilizes `Conv`, `Act`, and `Pool`.  Each Network requires an `__init__` and a `forward` function.

# %%
class MyNetwork(torch.nn.Module):
    
  def __init__(self, dims=3, in_channels=1, out_channels=8, kernel_size=3, pool_kernel=2, act="relu"):
    super(MyNetwork, self).__init__()
    # convolution
    self.conv = Conv[Conv.CONV, dims](in_channels, out_channels, kernel_size=kernel_size)
    # activation
    act_type, act_args = split_args(act)
    self.act = Act[act_type](**act_args)
    # pooling
    self.pool = Pool[Pool.MAX, dims](pool_kernel)
  
  def forward(self, x: torch.Tensor):
    x = self.conv(x)
    x = self.act(x)
    x = self.pool(x)
    return x

# %% [markdown]
# This network definition can be instantiated to support either 2D or 3D inputs, with flexible kernel sizes.  It becomes handy when adapting the same architecture design for different tasks, switching among 2D, 2.5D, 3D easily.
#
# Almost all the MONAI layers, blocks and networks are extensions of `torch.nn.modules` and follow this pattern. This makes the implementations compatible with any PyTorch pipelines and flexible with the network design. The current collections of those differentiable modules are listed in https://monai-dev.readthedocs.io/en/fixes-sphinx/networks.html.

# %%
# default network instance

print('')
print('***Default Network***')
default_net = MyNetwork()
print('Input size: ' , torch.ones(3, 1, 20, 20, 30).shape)
print(default_net)
print('Output Data Shape: ',default_net(torch.ones(3, 1, 20, 20, 30)).shape)
print('')
# 2D network instance
print('***Customize 2D Network***')
print('Input size: ' , torch.ones(3, 3, 24, 24).shape)
elu_net = MyNetwork(dims=2, in_channels=3, act=("elu", {"inplace": True}))
print(elu_net)
print('Output Data Shape: ',elu_net(torch.ones(3, 3, 24, 24)).shape)
print('')
# 3D network instance with anisotropic kernels
print('***Customize 3D Network***')
print('Input size: ' , torch.ones(3, 4, 30, 30, 5).shape)
sigmoid_net = MyNetwork(3, in_channels=4, kernel_size=(3, 3, 1), act="sigmoid")
print(sigmoid_net)
print('Output Data Shape: ',sigmoid_net(torch.ones(3, 4, 30, 30, 5)).shape)
# Out:
# ***Default Network***
# Input size:  torch.Size([3, 1, 20, 20, 30])
# MyNetwork(
#   (conv): Conv3d(1, 8, kernel_size=(3, 3, 3), stride=(1, 1, 1))
#   (act): ReLU()
#   (pool): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# )
# Output Data Shape:  torch.Size([3, 8, 9, 9, 14])
#
# ***Customize 2D Network***
# Input size:  torch.Size([3, 3, 24, 24])
# MyNetwork(
#   (conv): Conv2d(3, 8, kernel_size=(3, 3), stride=(1, 1))
#   (act): ELU(alpha=1.0, inplace=True)
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# )
# Output Data Shape:  torch.Size([3, 8, 11, 11])
#
# ***Customize 3D Network***
# Input size:  torch.Size([3, 4, 30, 30, 5])
# MyNetwork(
#   (conv): Conv3d(4, 8, kernel_size=(3, 3, 1), stride=(1, 1, 1))
#   (act): Sigmoid()
#   (pool): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# )
# Output Data Shape:  torch.Size([3, 8, 14, 14, 2])

# %% [markdown]
# MONAI provides over 20 Networks including:
# - UNet
# - VNet
# - AHNet
# - VGG-like regressor, classifier, discriminator, critic
# - HighResNet
# - SENet

# %% [markdown]
# ### Example UNets
#
# We'll define a 2D UNet network with 2 hidden layers having outputs with 8 and 16 channels, and a bottom (bottleneck) layer producing outputs with 32 channels.  The stride values state the stride for the initial convolution, ie. downsampling in down path and upsampling in up path and it'll transpose the convolutions used to implement upsampling.

# %%
net = monai.networks.nets.UNet(
    spatial_dims=2,  # 2 or 3 for a 2D or 3D network
    in_channels=1,  # number of input channels
    out_channels=1,  # number of output channels
    channels=[8, 16, 32],  # channel counts for layers
    strides=[2, 2]  # strides for mid layers
)

print(net)
# Out:
# UNet(
#   (model): Sequential(
#     (0): Convolution(
#       (conv): Conv2d(1, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (adn): ADN(
#         (N): InstanceNorm2d(8, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (D): Dropout(p=0.0, inplace=False)
#         (A): PReLU(num_parameters=1)
#       )
#     )
#     (1): SkipConnection(
#       (submodule): Sequential(
#         (0): Convolution(
#           (conv): Conv2d(8, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (adn): ADN(
#             (N): InstanceNorm2d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#             (D): Dropout(p=0.0, inplace=False)
#             (A): PReLU(num_parameters=1)
#           )
#         )
#         (1): SkipConnection(
#           (submodule): Convolution(
#             (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (adn): ADN(
#               (N): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#               (D): Dropout(p=0.0, inplace=False)
#               (A): PReLU(num_parameters=1)
#             )
#           )
#         )
#         (2): Convolution(
#           (conv): ConvTranspose2d(48, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#           (adn): ADN(
#             (N): InstanceNorm2d(8, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#             (D): Dropout(p=0.0, inplace=False)
#             (A): PReLU(num_parameters=1)
#           )
#         )
#       )
#     )
#     (2): Convolution(
#       (conv): ConvTranspose2d(16, 1, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     )
#   )
# )

# %% [markdown]
# Here we'll define a 4–layer 3D UNet with leaky ReLU activation in place of default PReLU.  THis time we'll instantiate the Act parameter which is the activation layer factory, and recalls names of known activation layers, eg. LEAKYRELU.  You can add custom layers to all factories.

# %%
net = monai.networks.nets.UNet(
    spatial_dims=3,  
    in_channels=1,      
    out_channels=1,  
    channels=[8, 16, 32, 64],
    strides=[2, 2, 2],
    act=monai.networks.layers.Act.LEAKYRELU
)

print(net)
# Out:
# UNet(
#   (model): Sequential(
#     (0): Convolution(
#       (conv): Conv3d(1, 8, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#       (adn): ADN(
#         (N): InstanceNorm3d(8, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (D): Dropout(p=0.0, inplace=False)
#         (A): LeakyReLU(negative_slope=0.01)
#       )
#     )
#     (1): SkipConnection(
#       (submodule): Sequential(
#         (0): Convolution(
#           (conv): Conv3d(8, 16, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#           (adn): ADN(
#             (N): InstanceNorm3d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#             (D): Dropout(p=0.0, inplace=False)
#             (A): LeakyReLU(negative_slope=0.01)
#           )
#         )
#         (1): SkipConnection(
#           (submodule): Sequential(
#             (0): Convolution(
#               (conv): Conv3d(16, 32, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#               (adn): ADN(
#                 (N): InstanceNorm3d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#                 (D): Dropout(p=0.0, inplace=False)
#                 (A): LeakyReLU(negative_slope=0.01)
#               )
#             )
#             (1): SkipConnection(
#               (submodule): Convolution(
#                 (conv): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#                 (adn): ADN(
#                   (N): InstanceNorm3d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#                   (D): Dropout(p=0.0, inplace=False)
#                   (A): LeakyReLU(negative_slope=0.01)
#                 )
#               )
#             )
#             (2): Convolution(
#               (conv): ConvTranspose3d(96, 16, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), output_padding=(1, 1, 1))
#               (adn): ADN(
#                 (N): InstanceNorm3d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#                 (D): Dropout(p=0.0, inplace=False)
#                 (A): LeakyReLU(negative_slope=0.01)
#               )
#             )
#           )
#         )
#         (2): Convolution(
#           (conv): ConvTranspose3d(32, 8, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), output_padding=(1, 1, 1))
#           (adn): ADN(
#             (N): InstanceNorm3d(8, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#             (D): Dropout(p=0.0, inplace=False)
#             (A): LeakyReLU(negative_slope=0.01)
#           )
#         )
#       )
#     )
#     (2): Convolution(
#       (conv): ConvTranspose3d(16, 1, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), output_padding=(1, 1, 1))
#     )
#   )
# )

# %% [markdown]
# ### Workflows
#
# MONAI includes extensions to Ignite Engine classes.  These workflow objects encompass the majority of the training process and provide default training loops and mechanism for responding to events.  This helps reduce code complexity and amount to be written for each experiment and are totally optional modules, other frameworks such as Lightning or Catalyst can be used instead.

# %% [markdown]
# ## **Summary**
#
# We've covered MONAI Datasets, Caching and Networks.  Here are some key highlights:
#
# - A MONAI Dataset is a generic dataset with a len property, getitem property, and an optional callable data transform when fetching a data sample.
# - You can use dataset caching to store dataset transforms to speed up training.  Some included Caching options are CachingDataset, PersistentCaching, and SmartCaching
# - MONAI provides access to some commonly used medical imaging datasets including the DecathlonDataset
# - Understanding the basic MONAI Layers, Blocks, and Networks
# - Use MONAI layers to implement a flexible network and instnaite a two UNet examples with different parameters

# %% [markdown]
# ## **Assignment 1**
#
# ### Instantiate a Dataset with SmartCache
#
# Requirements:
# - Write a transform that subtracts 1 from the input value
# - Combine the new Transform with the existing SlowSquare from above
# - Instantiate SmartCacheDataset with replacement rate of .2 and cache number of 5
# - Run SmartCache 5-times so that you can see the replacement values

# %%
from monai.data import SmartCacheDataset
from monai.transforms import Compose, MapTransform

class MinusOne(MapTransform):
    # constructor needed here?
    
    def __call__(self, x):
        pass # write code here

smart_transform = Compose([
    # ???
])    

smart_square = # ???

# %time for item in smart_square: print(item)

# %% [markdown]
# Below will utilize SmartCache

# %%
#Run through SmartCache replacement N-times
smart_square.start()

for i in range(5):
    print("\nCache: ", i)
    for item in smart_square: 
        print(item)
    smart_square.update_cache()
    
smart_square.shutdown()

# %% [markdown]
# ### **Assignment 2**
#
# Instantitate a network from the MONAI library. Inspect the output to see which composable layers were used in the network.

# %% [markdown]
# Some networks, such as UNet, are defined using template methods to create their layers. Experiment with extending one of these classes to change the composition of the created network by overriding these methods:

# %% [markdown]
# ## **Next Steps**

# %% [markdown]
# In this next notebook, we cover a MONAI end-to-end workflow.
#
# You can find more information about everything covered here on our [MONAI Documentation Page](https://docs.monai.io/).
#
# If you're looking for more examples and tutorials, we have a repo dedicated just to that!  You can find it on our [GitHub Organization Page](https://github.com/Project-MONAI/tutorials).
