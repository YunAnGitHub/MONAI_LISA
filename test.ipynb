# %% [markdown]
# # MONAI Environment Verification & Benchmarking
#
# **Author:** Yun-An Huang
# **Date:** March 7, 2025
#
# This notebook serves as a verification suite to ensure your computational environment is correctly configured for **MONAI (Medical Open Network for AI)** projects.
#
# ### 📋 Workflow Objectives:
# 1.  **Hardware Validation:** Confirm GPU availability and specifications to ensure 3D operations are performant.
# 2.  **Library Installation:** Setup PyTorch (optimized for CUDA 12.4) and the full MONAI framework suite.
# 3.  **Repository Setup:** Clone the official MONAI tutorials to access standardized 3D segmentation training pipelines.
# 4.  **Baseline Training:** Execute a 3D UNet training session using synthetic data to verify the end-to-end software stack.
# 5.  **Storage Integration:** Connect Google Drive for persistent model checkpointing and logging.

# %%
# Verify GPU availability and check the PyTorch installation environment

import torch

print("GPU Avalable:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU type:", torch.cuda.get_device_name(0))
# Out:
# GPU Avalable: True
# GPU type: Tesla T4

# %%
# Install PyTorch with CUDA 12.4 support and the MONAI framework with dependencies

# !pip install --index-url https://download.pytorch.org/whl/cu124 torch==2.6.0 torchvision==0.21.0 torchaudio==2.6.0
# !pip install "monai[all]" nibabel pydicom ipywidgets==8.1.2
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu124
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 85.3 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 62.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 113.1 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.6 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.1 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.6 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.8 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.2 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.3 MB/s eta 0:00:0000:0100:01
# ...

# %%
# Clone the Project-MONAI tutorials repository to access example training scripts

import os
if not os.path.exists("tutorials"):
    # !git clone https://github.com/Project-MONAI/tutorials.git

# %cd tutorials/3d_segmentation/torch
# Out:
# Cloning into 'tutorials'...
# remote: Enumerating objects: 8673, done.
# remote: Counting objects: 100% (599/599), done.
# remote: Compressing objects: 100% (421/421), done.
# remote: Total 8673 (delta 430), reused 178 (delta 178), pack-reused 8074 (from 3)
# Receiving objects: 100% (8673/8673), 331.19 MiB | 34.10 MiB/s, done.
# Resolving deltas: 100% (5137/5137), done.
# /content/tutorials/3d_segmentation/torch

# %%
# Execute a 3D UNet training session using synthetic data to verify the installation
# !python -u unet_training_array.py --max_epochs 2 --batch_size 1 --num_workers 2
# Out:
# 2026-05-28 13:27:07.848014: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# <frozen importlib._bootstrap_external>:1301: FutureWarning: The cuda.cudart module is deprecated and will be removed in a future release, please switch to use the cuda.bindings.runtime module instead.
# MONAI version: 1.5.2
# Numpy version: 2.4.6
# Pytorch version: 2.6.0+cu124
# MONAI flags: HAS_EXT = False, USE_COMPILED = False, USE_META_DICT = False
# MONAI rev id: d18565fb3e4fd8c556707f91ac280a2dc3f681c1
# MONAI __file__: /usr/local/lib/python3.12/dist-packages/monai/__init__.py
#
# Optional dependencies:
# Pytorch Ignite version: 0.4.11
# ITK version: 5.4.6
# Nibabel version: 5.4.2
# scikit-image version: 0.25.2
# scipy version: 1.16.3
# Pillow version: 11.3.0
# ...

# %%
# Optional: Mount Google Drive to persist trained model weights and logs

from google.colab import drive
import os

drive.mount('/content/drive/') # link to google drive

PROJECT_SANDBOX = "/content/drive/MyDrive/Colab_Workspace/MONAI_LISA" # link to specific working directory

print('Current Dir:')
print(os.listdir(PROJECT_SANDBOX)) # check the list
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# Current Dir:
# []
